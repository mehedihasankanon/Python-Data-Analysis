# %% [markdown]
# ### Data Analysis using Pandas
# coursera course

# %%
import pandas as pd, openpyxl
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd, openpyxl
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df = pd.read_excel("Travel_Records_Ctg_Dhaka.xlsx")

# %% [markdown]
# ## visulaize the first 23 rows of the dataframe

# %%
df.head(23)

# %% [markdown]
# ## visualize the last 10 rows of the dataframe

# %%
df.tail(10)

# %% [markdown]
# ## set the headers

# %%
headers = ["first", "second", "third", "fourth", "fifth", "sixth", "seventh", "eighth", "ninth", "tenth", "eleventh"]

df.columns = headers 
df.head(23)

# %% [markdown]
# ## Convert the dataframe to csv file

# %%
df.to_csv("myfile.csv")

# %% [markdown]
# ## dtype method
# check the datatypes of the columns

# %%
print(df.dtypes)
# Out:
# Serial         float64
# Date               str
# From               str
# To                 str
# Medium             str
# Cost             int64
# Unnamed: 6     float64
# Unnamed: 7         str
# Unnamed: 8      object
# Unnamed: 9      object
# Unnamed: 10     object
# dtype: object

# %% [markdown]
# ## statistical summary of the dataframe (describe)

# %%
# df.describe() 
df.describe(include = 'all')
# Out:
#           Serial         Date From     To   Medium          Cost  Unnamed: 6  \
# count   23.00000           23   23     23       23     24.000000         0.0
# unique       NaN           23    2      2        2           NaN         NaN
# top          NaN  27 Aug 2024  Ctg  Dhaka  (Train)           NaN         NaN
# freq         NaN            1   12     12       12           NaN         NaN
# mean    12.00000          NaN  NaN    NaN      NaN   1535.000000         NaN
# std      6.78233          NaN  NaN    NaN      NaN   3598.829218         NaN
# min      1.00000          NaN  NaN    NaN      NaN    520.000000         NaN
# 25%      6.50000          NaN  NaN    NaN      NaN    700.000000         NaN
# 50%     12.00000          NaN  NaN    NaN      NaN    875.000000         NaN
# 75%     17.50000          NaN  NaN    NaN      NaN    875.000000         NaN
# max     23.00000          NaN  NaN    NaN      NaN  18420.000000         NaN
#
# ...

# %% [markdown]
# ## info method

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Serial       23 non-null     float64
#  1   Date         23 non-null     str
#  2   From         23 non-null     str
#  3   To           23 non-null     str
#  4   Medium       23 non-null     str
#  5   Cost         24 non-null     int64
#  6   Unnamed: 6   0 non-null      float64
#  7   Unnamed: 7   6 non-null      str
#  8   Unnamed: 8   6 non-null      object
#  9   Unnamed: 9   6 non-null      object
#  10  Unnamed: 10  6 non-null      object
# dtypes: float64(2), int64(1), object(3), str(5)
# memory usage: 2.2+ KB
